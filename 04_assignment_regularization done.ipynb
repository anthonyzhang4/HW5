# %% [markdown]
# # Assignment 4: Regularization

# %% [markdown]
# **Q1.** Please answer the following questions in your own words.
#
# 1. What is the intuition of adding a penalty to mean squared error, that grows in the "size" (absolute or squared value) of the model parameters?
#
# Adding a penalty to the mean squared error stops it from making the coefficients super large to fit the trianing data better. It forces the model to stay simple and not overfit noise
# 2. How does regularization provide a way of exploring the bias-variance trade-off?
#
# Regularization allows us to have control over how complex we want the model to be by changing the penalty around. We move across the bias variance spectrum by either having a small penalty which equates to low bias/high variance versus a large penalty which equates to a high bias/low variance.
# 3. What is the difference between LASSO and Ridge regression? How do the answers typically change for the two problems?
#
# Ridge shrinks coefficients but keeps all coefficients while LASSO will shrink some coefficients to 0, performing feature selection to only pick the most important variables.
#
# 4. How do we typically scale variables for use in regularized regression? Why?
#
# We subtract mean and divide by standard deviation to standardize our variables and ensure that the penalty affects all variables the same.
#
# 5. How is the penalty $\alpha$ typically selected?
#
# We hand pick the alpha by cross validating a bunch of values and picking the one with the lowest validation error.
#
# 6. When conducting cross validation, do you include the penalty term in evaluating the cross validated MSE? Why or why not?
#
# No. You do not include the penalty term in evaluating the cross validated MSE because the penalty is only for training, not something we care about when looking at performance.

# %% [markdown]
# **Q2.** This is a case study on regularization.
#
# 1. Import the `cars_hw.csv` dataset. Create an `Age` variable for each vehicle. Take `Mileage_Run` and `Age`, and (a) use `PolynomialFeatures` to create a third degree expansion, (b) use `StandardScaler` to $z$-score normalize them.
# 2. Use your features, run linear regression. What is the sign for the interaction between `Mileage_Run` and `Age`?
# 3. Use `LassoCV` to regularize your linear regression, using 20-fold cross validation. (Hint: I used the grid `alphas = np.logspace(1,3,20)` to find the cost parameter)
# 4. Plot the cross-validated MSE by $\alpha$.
# 5. Plot the coefficient paths by $\alpha$.
# 6. Which features are actually selected? What proportion are set equal to zero?
# 7. Compare the linear regressions and optimally regularized coefficients. Do any coefficients increase in magnitude from linear regression to LASSO? Do any change sign?

# %%
#1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LassoCV, lasso_path
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

df = pd.read_csv('./data/cars_hw.csv')
df['Age'] = df['Make_Year'].max() - df['Make_Year']

X = df[['Mileage_Run', 'Age']]
y = df['Price']
poly = PolynomialFeatures(degree=3, include_bias=False)
X_poly = poly.fit_transform(X)
feature_names = poly.get_feature_names_out(X.columns)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_poly)

# %%
#2
ols = LinearRegression()
ols.fit(X_scaled, y)

ols_results = pd.DataFrame({
    'feature': feature_names,
    'ols_coef': ols.coef_
})
print(ols_results)

# The interaction between Mileage_Run and Age is negative.
# Out:
#              feature       ols_coef
# 0        Mileage_Run  458071.119627
# 1                Age -136698.072100
# 2      Mileage_Run^2  -91643.120024
# 3    Mileage_Run Age -898405.751356
# 4              Age^2  113603.822348
# 5      Mileage_Run^3  -65144.896599
# 6  Mileage_Run^2 Age  229021.676556
# 7  Mileage_Run Age^2  368955.713359
# 8              Age^3  -84038.066146

# %%
#3
alphas = np.logspace(1, 3, 20)

lasso = LassoCV(alphas=alphas, cv=20, max_iter=10000)
lasso.fit(X_scaled, y)
# Out:
# LassoCV(alphas=array([  10.        ,   12.74274986,   16.23776739,   20.69138081,
#          26.36650899,   33.59818286,   42.81332399,   54.55594781,
#          69.51927962,   88.58667904,  112.88378917,  143.84498883,
#         183.29807108,  233.57214691,  297.63514416,  379.26901907,
#         483.29302386,  615.84821107,  784.75997035, 1000.        ]),
#         cv=20, max_iter=10000)

# %%
#4
mean_mse = lasso.mse_path_.mean(axis=1)

plt.plot(lasso.alphas_, mean_mse)
plt.axvline(lasso.alpha_, color='yellow')
plt.xscale('log')
plt.xlabel('alpha')
plt.ylabel('MSE')
plt.title('MSE by Alpha')
# Out:
# Text(0.5, 1.0, 'MSE by Alpha')

# %%
#5
alphas_path, coefs, _ = lasso_path(X_scaled, y, alphas=alphas)

for i in range(coefs.shape[0]):
    plt.plot(alphas_path, coefs[i])

plt.axvline(lasso.alpha_, color= 'yellow')
plt.xscale('log')
plt.xlabel('Alpha')
plt.ylabel('Coefficient Value')
plt.title('Coefficients by LASSO')
plt.show()
# Out:
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141463082618.25, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 541616931508.0, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 571380444901.125, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547184350092.0, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 536792359124.625, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 532945760781.625, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 530389497709.25, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528185927921.875, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 515666410200.125, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 647887970164.5, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8921649654020.125, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14409260493988.812, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14289875028181.938, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13729887057917.875, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13644919500886.438, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13706157323897.375, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13739272059057.188, tolerance: 66748451500.0
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
#6
selected = lasso.coef_ != 0
print("Selected Features:", feature_names[selected])
prop_zero = (lasso.coef_ == 0).mean()
print(prop_zero)
#LASSO removed 33% of features which means 67% of features were selected.
# Out:
# Selected Features: ['Mileage_Run' 'Age' 'Mileage_Run Age' 'Mileage_Run^3' 'Mileage_Run Age^2'
#  'Age^3']
# 0.3333333333333333

# %% [markdown]
# #7 No coefficients increase in magnitude from regression to LASSO. A few coefficients change sign but only because LASSO set them to 0. My LASSO kept a lot of variables even including the higher order variables like Age^3 which was sort of strange to me.

# %% [markdown]
# **Q3.** This is a case study on regularization.
#
# 1. Import the `heart_failure_clinical_records_dataset.csv` dataset. Use `PolynomialFeatures` to create a third-degree expansion of `age`, `ejection_fraction`, and `serum_creatinine`, and then use `StandardScaler` to $z$-score normalize your results. Use `PolynomialFeatures` with `interaction_only=True` to interact the dummy/categorical variables `anaemia`, `diabetes`, `high_blood_pressure`, and `smoking`. Concatenate these results into your feature/covariate matrix.
# 2. Use your features, run linear regression. Are there any sign patterns that appear counterintuitive? Why? Can you see how the inclusion of higher-order powers or interactions might resolve the apparent contradiction?
# 3. Use `LassoCV` to regularize your linear regression, using 20-fold cross validation. (Hint: I used the grid `alphas = np.logspace(-5,5,30)` to find the cost parameter)
# 4. Plot the cross-validated MSE by $\alpha$.
# 5. Plot the coefficient paths by $\alpha$.
# 6. Which features are actually selected? What proportion are set equal to zero? Compare the linear regressions and optimally regularized coefficients. Do any coefficients increase in magnitude from linear regression to LASSO? Do any change sign? Do the sign patterns for the linear_model or the Lasso seem to make more sense? Explain why this might be the case from the perspective of the bias-variance trade-off.

# %%
#1
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LassoCV, lasso_path, LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

df = pd.read_csv('./data/heart_failure_clinical_records_dataset.csv')
print(df.head())

X_num = df[['age', 'ejection_fraction', 'serum_creatinine']]
poly_num = PolynomialFeatures(degree=3, include_bias=False)
X_num_poly = poly_num.fit_transform(X_num)
scaler = StandardScaler()
X_num_scaled = scaler.fit_transform(X_num_poly)

X_cat = df[['anaemia', 'diabetes', 'high_blood_pressure', 'smoking']]
poly_cat = PolynomialFeatures(degree=3, include_bias=False, interaction_only=True)
X_cat_poly = poly_cat.fit_transform(X_cat)

X = np.concatenate([X_cat_poly, X_num_scaled], axis=1)
y = df['DEATH_EVENT']
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
#2 + 3

from sklearn.linear_model import LinearRegression, LassoCV
ols = LinearRegression()
ols.fit(X, y)
ols_coef = ols.coef_
ols_results = pd.DataFrame({
    'feature': np.concatenate([
        poly_cat.get_feature_names_out(X_cat.columns),
        poly_num.get_feature_names_out(X_num.columns)
    ]),
    'linear_model': ols_coef
})
print(ols_results)

alpha_grid = np.logspace(-5, 5, 30)
lasso = LassoCV(alphas=alpha_grid, cv=20, max_iter=10000)
lasso.fit(X, y)

print("\nBest alpha:", lasso.alpha_)

# Some coefficients look to be counterintuitive when viewing them individually. 
# This is because the model has the higher order terms included so each variable's effect 
# is dependent on multiple coefficients rather than just the one that we are observing.
# Out:
#                                    feature  linear_model
# 0                                  anaemia     -0.043420
# 1                                 diabetes     -0.149472
# 2                      high_blood_pressure     -0.073480
# 3                                  smoking     -0.168209
# 4                         anaemia diabetes      0.137585
# 5              anaemia high_blood_pressure      0.040708
# 6                          anaemia smoking      0.139289
# 7             diabetes high_blood_pressure      0.282831
# 8                         diabetes smoking      0.337922
# 9              high_blood_pressure smoking      0.213817
# 10    anaemia diabetes high_blood_pressure     -0.167992
# 11                anaemia diabetes smoking     -0.224930
# 12     anaemia high_blood_pressure smoking     -0.029994
# 13    diabetes high_blood_pressure smoking     -0.310156
# 14                                     age      1.549928
# 15                       ejection_fraction     -2.025371
# 16                        serum_creatinine     -0.739027
# 17                                   age^2     -3.547991
# 18                   age ejection_fraction     -0.861860
# 19                    age serum_creatinine      1.680570
# 20                     ejection_fraction^2      3.317931
# 21      ejection_fraction serum_creatinine      2.604767
# 22                      serum_creatinine^2     -2.703084
# 23                                   age^3      1.889040
# 24                 age^2 ejection_fraction      1.022027
# 25                  age^2 serum_creatinine     -0.672141
# 26                 age ejection_fraction^2      0.017577
# 27  age ejection_fraction serum_creatinine     -1.584620
# 28                  age serum_creatinine^2      1.433246
# 29                     ejection_fraction^3     -1.253594
# 30    ejection_fraction^2 serum_creatinine     -1.219271
# 31    ejection_fraction serum_creatinine^2      1.217335
# 32                      serum_creatinine^3     -0.014908
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6609842553286391, tolerance: 0.005832394366197183
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.487941129557225, tolerance: 0.005832394366197183
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.314418656863397, tolerance: 0.005832394366197183
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.792553631256192, tolerance: 0.005832394366197183
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4123045927204245, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7369927735277102, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.194226766410804, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.425414925323032, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.784821877462395, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10689882788980043, tolerance: 0.005915492957746479
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.212248631694191, tolerance: 0.005915492957746479
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9283040618938827, tolerance: 0.005915492957746479
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.64807269251242, tolerance: 0.005915492957746479
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.948396254868522, tolerance: 0.005915492957746479
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06883693649989198, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.850740524052938, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4298051718834692, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.23092559920917, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.433422727999313, tolerance: 0.005874295774647888
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21054810848963967, tolerance: 0.005995774647887325
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0619630218459157, tolerance: 0.005995774647887325
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.3081485159509185, tolerance: 0.005995774647887325
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.371658350688758, tolerance: 0.005995774647887325
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.115972784005583, tolerance: 0.005995774647887325
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2641619403005535, tolerance: 0.006254577464788733
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9117807361045891, tolerance: 0.006254577464788733
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7810710119576143, tolerance: 0.006254577464788733
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.430724693224725, tolerance: 0.006254577464788733
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.442650720067371, tolerance: 0.006254577464788733
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23186558366469256, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8105946374796886, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6125226322091137, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.700076110836994, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.333685350284723, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033949206822285305, tolerance: 0.006219718309859154
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04334874656247223, tolerance: 0.006219718309859154
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.716684620311547, tolerance: 0.006219718309859154
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.919753700850755, tolerance: 0.006219718309859154
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.953117454438948, tolerance: 0.006219718309859154
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011270572991307404, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9006671343778834, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.831397328802833, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.889297475374969, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.855341014228934, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2414742274941375, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.516609957032621, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.1441603045473485, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.079167401432578, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.468970436519427, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.39447267628981564, tolerance: 0.006254577464788732
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3916131724113967, tolerance: 0.006254577464788732
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.940368574533302, tolerance: 0.006254577464788732
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.142168307917768, tolerance: 0.006254577464788732
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.615570774328795, tolerance: 0.006254577464788732
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19350834507609704, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.630746935459527, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.167373717082764, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.960954537304406, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.343063133167814, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006505408351053177, tolerance: 0.006073239436619717
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9079561681124417, tolerance: 0.006073239436619717
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.376264873631985, tolerance: 0.006073239436619717
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.158198529888992, tolerance: 0.006073239436619717
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.623434247673918, tolerance: 0.006073239436619717
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41695193238055595, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5419681155705547, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.462763648843733, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.25466866918549, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.310568628795542, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6066696943675538, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.7734478326990484, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.738723610987154, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.21941456604594, tolerance: 0.0062545774647887326
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010234122074407992, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4088188202110068, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.087749082502192, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.839193582475785, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.589157117821074, tolerance: 0.0063221830985915484
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3700509601403681, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.18385264879511, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.377631084263381, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.234402747545083, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.97452051658464, tolerance: 0.006322183098591549
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15175905406529466, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6700349074036751, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.401131171683907, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.881335946803638, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.278468232867738, tolerance: 0.006288732394366197
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4296121047318593, tolerance: 0.006354929577464787
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.43889610332673, tolerance: 0.006354929577464787
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.211412632397522, tolerance: 0.006354929577464787
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.3385949261771, tolerance: 0.006354929577464787
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.42897881197534815, tolerance: 0.006366315789473685
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8812493061270956, tolerance: 0.006366315789473685
#   model = cd_fast.enet_coordinate_descent_gram(
# Best alpha: 0.005736152510448681
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.869751407690394, tolerance: 0.006366315789473685
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.32718422236762, tolerance: 0.006366315789473685
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.830335312386268, tolerance: 0.006366315789473685
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
#4
mean_mse = lasso.mse_path_.mean(axis=1)

plt.plot(lasso.alphas_, mean_mse)
plt.axvline(lasso.alpha_, color='yellow')
plt.xscale('log')
plt.xlabel('Alpha')
plt.ylabel('MSE')
plt.title('Regularization Path using Lasso Cross Validation')
plt.show()

# %%
#5
alphas_path, coefs, _ = lasso_path(X, y, alphas=alpha_grid)

for coef in coefs:
    plt.plot(alphas_path, coef)
plt.axvline(lasso.alpha_, color='red')
plt.xscale('log')

plt.xlabel('Alpha')
plt.ylabel('Coefficient')
plt.title('LASSO Coefficient Paths')

plt.show()
# Out:
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13494852194989448, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012170379526601494, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.892157344167547, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.013834592305118, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.89740118876647, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.14748714040743, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\antho\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.769045027589026, tolerance: 0.009600000000000001
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
#6
names = np.concatenate([
    poly_cat.get_feature_names_out(X_cat.columns),
    poly_num.get_feature_names_out(X_num.columns)
])
results = pd.DataFrame({
    'feature': names,
    'linear_model': ols_coef,
    'lasso': lasso.coef_
})
selected = np.where(lasso.coef_ != 0)[0]
print(selected)
print(names[selected])
print(f'Proportion, Variables selected: {len(selected)/len(names)}')

results

#LASSO keeps about 36% of the features and sets the rest to zero, making the model much simpler than  linear 
# regression. It also fixes some of the weird signs from OLS, like risk factors going from negative to positive, 
# since regularization reduces overfitting and gives more stable and more intuitive results.
# Out:
# [ 0  1  2  7  8  9 15 16 23 29 30 32]
# ['anaemia' 'diabetes' 'high_blood_pressure' 'diabetes high_blood_pressure'
#  'diabetes smoking' 'high_blood_pressure smoking' 'ejection_fraction'
#  'serum_creatinine' 'age^3' 'ejection_fraction^3'
#  'ejection_fraction^2 serum_creatinine' 'serum_creatinine^3']
# Proportion, Variables selected: 0.36363636363636365
#                                    feature  linear_model     lasso
# 0                                  anaemia     -0.043420  0.014177
# 1                                 diabetes     -0.149472  0.000609
# 2                      high_blood_pressure     -0.073480  0.013609
# 3                                  smoking     -0.168209 -0.000000
# 4                         anaemia diabetes      0.137585  0.000000
# 5              anaemia high_blood_pressure      0.040708  0.000000
# 6                          anaemia smoking      0.139289  0.000000
# 7             diabetes high_blood_pressure      0.282831  0.053965
# 8                         diabetes smoking      0.337922  0.003466
# 9              high_blood_pressure smoking      0.213817  0.017803
# 10    anaemia diabetes high_blood_pressure     -0.167992  0.000000
# 11                anaemia diabetes smoking     -0.224930  0.000000
# 12     anaemia high_blood_pressure smoking     -0.029994  0.000000
# 13    diabetes high_blood_pressure smoking     -0.310156  0.000000
# 14                                     age      1.549928 -0.000000
# 15                       ejection_fraction     -2.025371 -0.329655
# 16                        serum_creatinine     -0.739027  0.116875
# 17                                   age^2     -3.547991  0.000000
# 18                   age ejection_fraction     -0.861860 -0.000000
# 19                    age serum_creatinine      1.680570  0.000000
# 20                     ejection_fraction^2      3.317931  0.000000
# 21      ejection_fraction serum_creatinine      2.604767  0.000000
# 22                      serum_creatinine^2     -2.703084 -0.000000
# 23                                   age^3      1.889040  0.117992
# 24                 age^2 ejection_fraction      1.022027  0.000000
# 25                  age^2 serum_creatinine     -0.672141  0.000000
# 26                 age ejection_fraction^2      0.017577  0.000000
# 27  age ejection_fraction serum_creatinine     -1.584620  0.000000
# 28                  age serum_creatinine^2      1.433246 -0.000000
# 29                     ejection_fraction^3     -1.253594  0.204821
# 30    ejection_fraction^2 serum_creatinine     -1.219271  0.032801
# 31    ejection_fraction serum_creatinine^2      1.217335 -0.000000
# 32                      serum_creatinine^3     -0.014908 -0.043266

# %% [markdown]
# **Q4.** To better understand the math of regularization, we'll solve the regularized linear model problem with a single explanatory variable. So, the model is
# $$
# \tilde{y}_i = \tilde{b}_0 + \tilde{b}_1 \tilde{x}_i,
# $$
# where
# $$
# \tilde{y}_i = y_i - \bar{y} \quad \text{ and } \quad \tilde{x}_i = x_i - \bar{x}.
# $$
#
# Recall, we do this mean-normalization of $x$ and $y$, because
# $$
# \frac{1}{n} \sum_{i=1}^n \tilde{y} = \frac{1}{n} \sum_{i=1}^n y_i - \bar{y} = 0,
# $$
# and likewise for $x$. This trick makes the calculations easier and the results more easily interpretable.
#
# 1. To do ridge regression, add a penalty $+ \alpha (b_1)^2$ to mean squared error. What is the objective function for this problem?
#
# 2. Take the derivatives of your objective function with respect to $b_0$ and $b_1$. Set these equations equal to zero. Solve the two equations in two unknowns for $b_1$ and $b_0$.
# 3. How does increasing $\alpha$ change the slope coefficient?
#
# As alpha increases, the slope coefficient decreases.
# 4. If we instead used the LASSO/L1 penalty, $+\alpha |b_1|$, what challenge do you run into? This is conceptually difficult, but take 5 minutes and try to figure out the solution, and in particular, when is it optimal to set $b_1=0$?
#
# The challenge is that the derivative of |x| at zero is undefined so solving the equations becomes harder.

# %%
#1
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('IMG_3747.JPG') 
plt.imshow(img)
plt.show()

# %%
#2
img = mpimg.imread('IMG_3748.JPG') 
plt.imshow(img)
plt.show()
